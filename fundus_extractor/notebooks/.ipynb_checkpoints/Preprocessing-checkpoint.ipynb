# %%
# %load_ext autoreload

# %%
import os
import sys
import random
from typing import Tuple
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torchvision
import torchvision.transforms as T

# %%
# %autoreload 2
from fundus_extractor.utils.general import imshow

# %%
class ImageOutOfDistributionError(Exception):
    pass

# %%
def resize_image(image: torch.Tensor, image_resize_size: int) -> torch.Tensor:
    return T.functional.resize(image, (image_resize_size, image_resize_size))


def cut_image(image: torch.Tensor, threshold: float = 0.2, min_gray: float = 0.05)-> torch.Tensor:
    gray_image = T.functional.rgb_to_grayscale(image) / 255
    threshold *= torch.mean(gray_image).item()

    # Threshold the grayscale image
    binary_mask = (gray_image > threshold).float()[0]
    if binary_mask.shape[0] < 150 or binary_mask.shape[1] < 150:
        raise ImageOutOfDistributionError()

    cols = torch.mean(binary_mask, dim=0) > min_gray
    left, right = torch.min(torch.where(cols)[0]), torch.max(torch.where(cols)[0])

    rows = torch.mean(binary_mask, dim=1) > min_gray
    top, bottom = torch.min(torch.where(rows)[0]), torch.max(torch.where(rows)[0])

    # Crop the image based on the contour boundaries
    return image[:, top:bottom, left:right]


def pad_to_square(image: torch.Tensor) -> torch.Tensor:
    _, width, height = image.shape

    # Determine the maximum dimension
    max_dim = max(width, height)

    # Calculate the padding amounts
    pad_width = max_dim - width
    pad_height = max_dim - height

    # Calculate the padding values for top, bottom, left, and right
    pad_top = pad_height // 2
    pad_bottom = pad_height - pad_top
    pad_left = pad_width // 2
    pad_right = pad_width - pad_left

    # Pad the image with zeros
    return torch.nn.functional.pad(image, (pad_top, pad_bottom, pad_left, pad_right))

# %% [markdown]
# ### Random Test

# %%
image_dir = '/s/project/deepMMR/data/fundus/raw/left/00'
image_file_name = random.choice(os.listdir(image_dir))
image_path = os.path.join(image_dir, image_file_name)
print(image_path)

image_raw = torchvision.io.read_image(image_path)
cropped_image = cut_image(image_raw)
padded_image = pad_to_square(cropped_image)
resized_image = resize_image(padded_image, 224)

imshow(image_raw)
imshow(cropped_image)
imshow(padded_image)
imshow(resized_image)
# Out:
# /s/project/deepMMR/data/fundus/raw/left/00/1007216_21015_0_0.png
# /opt/modules/i12g/anaconda/envs/deepMMR/lib/python3.8/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ### Pipeline

# %%
image_dir = '/s/project/deepMMR/data/fundus/raw/left'
save_dir = '/s/project/deepMMR/data/fundus/processed/left'

for sub_folder in os.listdir(image_dir):
    os.makedirs(os.path.join(save_dir, sub_folder), exist_ok=True)

    for image_file_name in tqdm([img for img in os.listdir(os.path.join(image_dir, sub_folder)) if img.endswith('png')]):
        try:
            file_path = os.path.join(image_dir, sub_folder, image_file_name)
            save_file_path = os.path.join(save_dir, sub_folder, image_file_name)
            eid, fid, instance_id, array_id = file_path.split('.')[0].split('_')

            image_raw = torchvision.io.read_image(file_path)
            cropped_image = cut_image(image_raw)
            padded_image = pad_to_square(cropped_image)
            resized_image = resize_image(padded_image, 224)
            torchvision.utils.save_image(resized_image / 255, save_file_path)
        except ImageOutOfDistributionError as e:
            imshow(torchvision.io.read_image(image_path))
            print(image_file_name)
        except Exception as e:
            print(image_file_name)
            print(e)
# Out:
# 100%|██████████| 500/500 [01:09<00:00,  7.21it/s]
#  32%|███▏      | 160/500 [00:21<00:51,  6.54it/s]
# 1613884_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.12it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.23it/s]
#  61%|██████    | 304/500 [00:42<00:22,  8.67it/s]
# 1233653_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:09<00:00,  7.24it/s]
#   5%|▌         | 26/500 [00:03<00:46, 10.27it/s]
# 5159620_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.08it/s]
# 100%|██████████| 500/500 [01:06<00:00,  7.53it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.24it/s]
#  11%|█         | 53/500 [00:07<00:58,  7.70it/s]
# 3390463_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  80%|███████▉  | 398/500 [00:58<00:13,  7.77it/s]
# 3380762_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.98it/s]
#  11%|█         | 53/500 [00:06<00:53,  8.35it/s]
# 1550502_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  45%|████▍     | 224/500 [00:31<00:31,  8.85it/s]
# 1550687_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  7.02it/s]
#  54%|█████▍    | 271/500 [00:42<00:31,  7.19it/s]
# 3096079_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.82it/s]
#  21%|██        | 105/500 [00:16<00:51,  7.66it/s]
# 5723043_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.95it/s]
# 100%|██████████| 500/500 [01:08<00:00,  7.25it/s]
# 100%|██████████| 500/500 [01:10<00:00,  7.08it/s]
#  70%|██████▉   | 348/500 [00:46<00:18,  8.22it/s]
# 5008712_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  86%|████████▌ | 430/500 [00:59<00:07,  9.43it/s]
# 5009001_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:08<00:00,  7.26it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.15it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.15it/s]
#  68%|██████▊   | 341/500 [00:47<00:20,  7.92it/s]
# 3985286_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  85%|████████▌ | 426/500 [01:00<00:09,  8.07it/s]
# 3970617_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  89%|████████▉ | 444/500 [01:02<00:07,  7.24it/s]
# 3989854_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.09it/s]
#  59%|█████▊    | 293/500 [00:39<00:23,  8.94it/s]
# 3206142_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  91%|█████████▏| 457/500 [01:03<00:04,  8.78it/s]
# 3204271_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:08<00:00,  7.27it/s]
#  23%|██▎       | 113/500 [00:15<00:47,  8.19it/s]
# 3421683_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  25%|██▍       | 123/500 [00:17<00:43,  8.75it/s]
# 3412044_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  84%|████████▎ | 418/500 [00:59<00:09,  8.59it/s]
# 3423042_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.11it/s]
#  53%|█████▎    | 263/500 [00:35<00:31,  7.46it/s]
# 5222221_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.14it/s]
#  97%|█████████▋| 484/500 [01:03<00:01,  9.06it/s]
# 4096952_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:06<00:00,  7.50it/s]
#  17%|█▋        | 83/500 [00:12<00:43,  9.54it/s]
# 5458757_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  24%|██▍       | 120/500 [00:16<00:47,  8.06it/s]
# 5477435_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  36%|███▌      | 179/500 [00:25<00:37,  8.58it/s]
# 5457607_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:06<00:00,  7.47it/s]
#  86%|████████▌ | 430/500 [01:04<00:08,  8.36it/s]
# 3567398_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:15<00:00,  6.61it/s]
#   3%|▎         | 16/500 [00:01<00:50,  9.65it/s]
# 4015046_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  48%|████▊     | 240/500 [00:36<00:31,  8.27it/s]
# 4014752_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  48%|████▊     | 242/500 [00:36<00:33,  7.61it/s]
# 4014022_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  54%|█████▍    | 272/500 [00:41<00:29,  7.81it/s]
# 4019535_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.32it/s]
#  97%|█████████▋| 486/500 [01:11<00:01,  7.87it/s]
# 2671645_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.80it/s]
#  50%|█████     | 251/500 [00:36<00:28,  8.59it/s]
# 1140947_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  77%|███████▋  | 386/500 [00:55<00:19,  5.97it/s]
# 1122787_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.82it/s]
# 100%|██████████| 500/500 [01:15<00:00,  6.63it/s]
#  14%|█▍        | 72/500 [00:10<00:46,  9.22it/s]
# 2728747_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.71it/s]
#  30%|███       | 152/500 [00:21<00:52,  6.60it/s]
# 3604026_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  80%|████████  | 401/500 [00:59<00:12,  8.02it/s]
# 3620046_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.79it/s]
#  13%|█▎        | 64/500 [00:09<00:49,  8.76it/s]
# 2971710_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  79%|███████▉  | 395/500 [00:59<00:12,  8.27it/s]
# 2987246_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:13<00:00,  6.81it/s]
# 100%|██████████| 500/500 [01:15<00:00,  6.62it/s]
# 100%|██████████| 500/500 [01:14<00:00,  6.69it/s]
#  64%|██████▍   | 319/500 [00:51<00:23,  7.62it/s]
# 1892143_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:17<00:00,  6.46it/s]
#  80%|████████  | 402/500 [01:00<00:11,  8.71it/s]
# 3710853_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.69it/s]
# 100%|██████████| 500/500 [01:17<00:00,  6.47it/s]
#  12%|█▏        | 59/500 [00:08<00:57,  7.73it/s]
# 4748437_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  15%|█▍        | 74/500 [00:10<00:57,  7.35it/s]
# 4755009_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  36%|███▌      | 181/500 [00:27<00:38,  8.29it/s]
# 4755420_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.88it/s]
#  40%|███▉      | 199/500 [00:29<00:33,  8.99it/s]
# 3118265_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.93it/s]
#  52%|█████▏    | 258/500 [00:37<00:29,  8.26it/s]
# 5873465_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.06it/s]
# 100%|██████████| 500/500 [01:14<00:00,  6.67it/s]
# 100%|██████████| 500/500 [01:12<00:00,  6.90it/s]
#   1%|          | 5/500 [00:00<00:53,  9.31it/s]
# 3364606_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  62%|██████▏   | 312/500 [00:45<00:26,  7.01it/s]
# 3349732_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  99%|█████████▊| 493/500 [01:14<00:00,  8.22it/s]
# 3356649_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:15<00:00,  6.62it/s]
#  53%|█████▎    | 265/500 [00:38<00:32,  7.32it/s]
# 1370016_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.86it/s]
#  71%|███████   | 354/500 [01:23<01:25,  1.71it/s]
# 2328761_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [05:15<00:00,  1.59it/s]
#  59%|█████▊    | 293/500 [00:54<00:25,  8.27it/s]
# 2530830_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:28<00:00,  5.64it/s]
# 100%|██████████| 500/500 [01:18<00:00,  6.40it/s]
#  58%|█████▊    | 292/500 [00:41<00:23,  9.04it/s]
# 5384944_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:16<00:00,  6.54it/s]
#   2%|▏         | 8/500 [00:01<01:07,  7.32it/s]
# 4220436_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  45%|████▌     | 225/500 [00:33<00:30,  8.92it/s]
# 4241011_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  80%|███████▉  | 398/500 [01:00<00:13,  7.35it/s]
# 4223174_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:16<00:00,  6.51it/s]
# 100%|██████████| 500/500 [01:13<00:00,  6.81it/s]
#  23%|██▎       | 115/500 [00:16<00:52,  7.33it/s]
# 2994369_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  56%|█████▌    | 279/500 [00:41<00:26,  8.35it/s]
# 2988096_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.87it/s]
#  28%|██▊       | 142/500 [00:19<00:43,  8.22it/s]
# 2902986_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:13<00:00,  6.79it/s]
# 100%|██████████| 500/500 [01:08<00:00,  7.27it/s]
#  48%|████▊     | 239/500 [00:36<00:26,  9.83it/s]
# 2484764_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  57%|█████▋    | 284/500 [00:44<00:25,  8.59it/s]
# 2494336_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  62%|██████▏   | 308/500 [00:48<00:38,  5.00it/s]
# 2482532_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:15<00:00,  6.63it/s]
#  96%|█████████▌| 478/500 [01:08<00:02,  9.48it/s]
# 1101000_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  7.04it/s]
#  25%|██▌       | 125/500 [00:19<00:41,  9.04it/s]
# 2576533_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  89%|████████▉ | 446/500 [01:04<00:05,  9.55it/s]
# 2578464_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.95it/s]
#  19%|█▉        | 94/500 [00:13<00:43,  9.23it/s]
# 4400155_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  57%|█████▋    | 285/500 [00:40<00:25,  8.42it/s]
# 4400694_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.04it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.17it/s]
#  50%|█████     | 252/500 [00:34<00:30,  8.19it/s]
# 4862332_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  82%|████████▏ | 409/500 [00:56<00:11,  7.62it/s]
# 4871436_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  99%|█████████▉| 494/500 [01:10<00:01,  5.69it/s]
# 4866122_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.98it/s]
#  48%|████▊     | 242/500 [00:35<00:44,  5.80it/s]
# 2432764_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:15<00:00,  6.64it/s]
#  36%|███▌      | 181/500 [00:26<00:40,  7.90it/s]
# 1315489_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.70it/s]
#  24%|██▍       | 122/500 [00:16<00:49,  7.69it/s]
# 3762465_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.80it/s]
#  35%|███▍      | 173/500 [00:26<00:40,  8.04it/s]
# 1990263_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  38%|███▊      | 189/500 [00:28<00:43,  7.22it/s]
# 1988109_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.69it/s]
#  95%|█████████▍| 473/500 [01:10<00:03,  8.74it/s]
# 4842919_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:14<00:00,  6.70it/s]
# 100%|██████████| 500/500 [01:12<00:00,  6.85it/s]
#  58%|█████▊    | 291/500 [00:45<00:26,  7.83it/s]
# 4364360_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:15<00:00,  6.62it/s]
#  17%|█▋        | 87/500 [00:12<01:04,  6.39it/s]
# 5447019_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  64%|██████▎   | 318/500 [00:44<00:18,  9.72it/s]
# 5433319_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  81%|████████  | 406/500 [00:56<00:10,  8.56it/s]
# 5434953_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  93%|█████████▎| 466/500 [01:05<00:03,  9.01it/s]
# 5439237_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:09<00:00,  7.17it/s]
# 100%|██████████| 500/500 [01:08<00:00,  7.25it/s]
#  15%|█▌        | 77/500 [00:10<00:48,  8.75it/s]
# 3729398_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.11it/s]
#  13%|█▎        | 64/500 [00:08<00:51,  8.54it/s]
# 5847251_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  38%|███▊      | 192/500 [00:26<00:43,  7.15it/s]
# 5849843_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:07<00:00,  7.40it/s]
#  29%|██▉       | 146/500 [00:22<00:38,  9.29it/s]
# 3481655_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:08<00:00,  7.27it/s]
#  24%|██▎       | 118/500 [00:17<00:39,  9.69it/s]
# 2788715_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  7.02it/s]
#  65%|██████▌   | 327/500 [00:49<00:22,  7.75it/s]
# 3941006_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.77it/s]
#   1%|          | 4/500 [00:00<00:48, 10.28it/s]
# 5628667_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:20<00:00,  6.19it/s]
#  16%|█▌        | 81/500 [00:11<00:51,  8.17it/s]
# 2241471_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  29%|██▉       | 146/500 [00:20<00:39,  9.01it/s]
# 2244338_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  46%|████▌     | 229/500 [00:31<00:32,  8.37it/s]
# 2231265_21015_0_1.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:12<00:00,  6.87it/s]
#  24%|██▍       | 119/500 [00:16<00:46,  8.20it/s]
# 2076536_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  34%|███▍      | 172/500 [00:24<00:43,  7.56it/s]
# 2100025_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.77it/s]
#  17%|█▋        | 83/500 [00:12<00:51,  8.08it/s]
# 4176883_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  24%|██▎       | 118/500 [00:17<00:45,  8.41it/s]
# 4163341_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  30%|███       | 152/500 [00:22<00:45,  7.64it/s]
# 4164376_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.90it/s]
#  25%|██▍       | 124/500 [00:17<00:43,  8.56it/s]
# 2829107_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  45%|████▌     | 225/500 [00:32<00:32,  8.53it/s]
# 2825758_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.98it/s]
#  59%|█████▊    | 293/500 [00:39<00:26,  7.84it/s]
# 2217165_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:09<00:00,  7.14it/s]
#  44%|████▍     | 220/500 [00:29<00:29,  9.52it/s]
# 1339380_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  58%|█████▊    | 292/500 [00:42<00:41,  5.03it/s]
# 1335856_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:11<00:00,  7.01it/s]
#   7%|▋         | 36/500 [00:04<01:00,  7.63it/s]
# 3834819_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  61%|██████    | 304/500 [00:43<00:24,  7.89it/s]
# 3845480_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.98it/s]
#   5%|▌         | 26/500 [00:03<01:00,  7.85it/s]
# 1813601_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.05it/s]
#   3%|▎         | 13/500 [00:01<00:54,  8.87it/s]
# 4788413_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:13<00:00,  6.78it/s]
#  61%|██████    | 305/500 [00:45<00:25,  7.59it/s]
# 3271720_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:15<00:00,  6.64it/s]
#   2%|▏         | 10/500 [00:01<01:13,  6.70it/s]
# 4261091_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  79%|███████▉  | 394/500 [01:02<00:13,  8.14it/s]
# 4262757_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  85%|████████▍ | 424/500 [01:06<00:08,  9.08it/s]
# 4254041_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:17<00:00,  6.45it/s]
# 100%|██████████| 500/500 [01:12<00:00,  6.92it/s]
#  13%|█▎        | 65/500 [00:10<00:48,  9.01it/s]
# 4903511_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  93%|█████████▎| 465/500 [01:08<00:04,  8.73it/s]
# 4910702_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:15<00:00,  6.66it/s]
#  85%|████████▌ | 427/500 [01:01<00:08,  8.87it/s]
# 3125451_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.83it/s]
#  15%|█▌        | 75/500 [00:10<00:46,  9.19it/s]
# 4816517_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  64%|██████▍   | 319/500 [00:46<00:19,  9.19it/s]
# 4807813_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  85%|████████▌ | 425/500 [01:06<00:08,  9.08it/s]
# 4801514_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:16<00:00,  6.56it/s]
# 100%|██████████| 500/500 [01:10<00:00,  7.08it/s]
#  72%|███████▏  | 361/500 [00:54<00:19,  7.22it/s]
# 3038896_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.74it/s]
# 100%|██████████| 500/500 [01:11<00:00,  6.98it/s]
#  12%|█▏        | 62/500 [00:09<00:52,  8.38it/s]
# 1682614_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  73%|███████▎  | 365/500 [00:55<00:15,  8.78it/s]
# 1689537_21015_1_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:14<00:00,  6.75it/s]
# 100%|██████████| 500/500 [01:13<00:00,  6.78it/s]
#  29%|██▉       | 145/500 [00:20<00:49,  7.23it/s]
# 3335540_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  68%|██████▊   | 339/500 [00:50<00:18,  8.54it/s]
# 3330871_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  88%|████████▊ | 442/500 [01:04<00:07,  7.90it/s]
# 3338114_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:12<00:00,  6.90it/s]
#   4%|▎         | 18/500 [00:02<00:51,  9.42it/s]
# 4563817_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  30%|██▉       | 148/500 [00:20<00:35,  9.80it/s]
# 4556818_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  86%|████████▌ | 431/500 [01:03<00:10,  6.36it/s]
# 4559939_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.90it/s]
# 100%|██████████| 500/500 [01:09<00:00,  7.15it/s]
#  15%|█▍        | 74/500 [00:10<00:51,  8.27it/s]
# 5551472_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:08<00:00,  7.27it/s]
# 100%|██████████| 500/500 [01:10<00:00,  7.13it/s]
#  32%|███▏      | 160/500 [00:24<00:41,  8.23it/s]
# 1852511_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.12it/s]
# 100%|██████████| 500/500 [01:11<00:00,  7.01it/s]
#  87%|████████▋ | 434/500 [01:05<00:07,  9.22it/s]
# 2474432_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:14<00:00,  6.69it/s]
#  89%|████████▉ | 446/500 [01:04<00:06,  8.67it/s]
# 3930386_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  91%|█████████ | 455/500 [01:05<00:07,  6.16it/s]
# 3934641_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.92it/s]
# 100%|██████████| 500/500 [01:13<00:00,  6.77it/s]
#  13%|█▎        | 63/500 [00:08<00:45,  9.51it/s]
# 4621026_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:13<00:00,  6.81it/s]
#  28%|██▊       | 142/500 [00:20<00:46,  7.74it/s]
# 5065435_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.89it/s]
# 100%|██████████| 500/500 [01:11<00:00,  6.96it/s]
# 100%|██████████| 500/500 [01:19<00:00,  6.31it/s]
# 100%|██████████| 500/500 [01:13<00:00,  6.76it/s]
#  91%|█████████ | 456/500 [01:08<00:05,  8.25it/s]
# 2945933_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:14<00:00,  6.70it/s]
#  77%|███████▋  | 387/500 [00:55<00:11,  9.77it/s]
# 4980807_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:10<00:00,  7.05it/s]
# 100%|██████████| 500/500 [01:13<00:00,  6.81it/s]
# 100%|██████████| 219/219 [00:31<00:00,  6.94it/s]
#  14%|█▍        | 70/500 [00:08<00:46,  9.16it/s]
# 5422394_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  49%|████▉     | 247/500 [00:33<00:30,  8.42it/s]
# 5401852_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  69%|██████▉   | 344/500 [00:46<00:15, 10.24it/s]
# 5422151_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  72%|███████▏  | 361/500 [00:49<00:14,  9.53it/s]
# 5405589_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  80%|███████▉  | 398/500 [00:53<00:13,  7.77it/s]
# 5401137_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  95%|█████████▍| 474/500 [01:06<00:02,  8.71it/s]
# 5408335_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:09<00:00,  7.19it/s]
#  98%|█████████▊| 490/500 [01:10<00:01,  6.88it/s]
# 2540093_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:11<00:00,  6.97it/s]
#  24%|██▎       | 118/500 [00:17<00:42,  8.96it/s]
# 4711101_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  90%|████████▉ | 449/500 [01:05<00:05,  8.86it/s]
# 4699173_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:12<00:00,  6.90it/s]
# 100%|██████████| 500/500 [01:12<00:00,  6.85it/s]
#  28%|██▊       | 139/500 [00:18<00:43,  8.30it/s]
# 5526070_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  52%|█████▏    | 262/500 [00:35<00:28,  8.46it/s]
# 5509560_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|█████████▉| 498/500 [01:15<00:00,  8.51it/s]
# 5517542_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:15<00:00,  6.63it/s]
# 100%|██████████| 500/500 [01:19<00:00,  6.28it/s]
#  78%|███████▊  | 391/500 [01:01<00:16,  6.55it/s]
# 3856604_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.28it/s]
# 100%|██████████| 500/500 [01:19<00:00,  6.32it/s]
#  46%|████▌     | 231/500 [00:36<00:35,  7.51it/s]
# 5183592_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:19<00:00,  6.31it/s]
#  26%|██▌       | 131/500 [00:20<00:47,  7.74it/s]
# 5738810_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [02:26<00:00,  3.41it/s]
#  71%|███████   | 353/500 [03:48<00:21,  6.69it/s]
# 2174297_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  87%|████████▋ | 436/500 [04:03<00:15,  4.24it/s]
# 2166945_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [04:14<00:00,  1.96it/s]
#  53%|█████▎    | 267/500 [00:47<00:35,  6.57it/s]
# 2300710_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:30<00:00,  5.51it/s]
#   7%|▋         | 35/500 [00:06<01:30,  5.16it/s]
# 4723537_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  58%|█████▊    | 290/500 [00:54<00:28,  7.30it/s]
# 4723734_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:33<00:00,  5.32it/s]
#   2%|▏         | 12/500 [00:01<01:08,  7.16it/s]
# 3655521_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#   5%|▍         | 23/500 [00:03<01:00,  7.92it/s]
# 3667002_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  61%|██████    | 305/500 [00:51<00:25,  7.59it/s]
# 3662213_21015_1_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  79%|███████▊  | 393/500 [01:09<00:15,  6.70it/s]
# 3675358_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:26<00:00,  5.77it/s]
# 100%|██████████| 500/500 [01:39<00:00,  5.03it/s]
#  11%|█         | 53/500 [00:11<00:59,  7.55it/s]
# 2726167_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
#  70%|███████   | 351/500 [01:03<00:25,  5.76it/s]
# 2702799_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:32<00:00,  5.43it/s]
#  38%|███▊      | 190/500 [00:36<00:42,  7.28it/s]
# 1630927_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:51<00:00,  4.47it/s]
#  41%|████      | 204/500 [00:43<01:15,  3.93it/s]
# 2644774_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:41<00:00,  4.93it/s]
# 100%|██████████| 500/500 [01:28<00:00,  5.62it/s]
#  15%|█▌        | 75/500 [00:15<00:55,  7.64it/s]
# 5591780_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:29<00:00,  5.58it/s]
#  36%|███▌      | 178/500 [00:30<00:39,  8.05it/s]
# 1720377_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  77%|███████▋  | 385/500 [01:09<00:16,  7.17it/s]
# 1711006_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:28<00:00,  5.68it/s]
#  16%|█▌        | 80/500 [00:12<01:08,  6.14it/s]
# 2136439_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:24<00:00,  5.90it/s]
#  34%|███▍      | 169/500 [00:29<00:54,  6.11it/s]
# 3162490_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  41%|████      | 204/500 [00:35<00:44,  6.61it/s]
# 3156363_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:25<00:00,  5.83it/s]
# 100%|██████████| 500/500 [01:24<00:00,  5.89it/s]
#  71%|███████▏  | 357/500 [01:02<00:22,  6.41it/s]
# 3651712_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:28<00:00,  5.62it/s]
#  30%|███       | 151/500 [00:24<00:45,  7.69it/s]
# 4438493_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  83%|████████▎ | 416/500 [01:08<00:09,  8.52it/s]
# 4444416_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:21<00:00,  6.13it/s]
#  49%|████▉     | 246/500 [00:41<00:48,  5.22it/s]
# 2639263_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  58%|█████▊    | 291/500 [00:48<00:26,  7.84it/s]
# 2625782_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  70%|██████▉   | 349/500 [00:56<00:17,  8.54it/s]
# 2637371_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:21<00:00,  6.12it/s]
#  29%|██▉       | 145/500 [00:25<00:39,  8.99it/s]
# 5571625_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  58%|█████▊    | 290/500 [00:51<00:26,  7.93it/s]
# 5571072_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:27<00:00,  5.73it/s]
# 100%|██████████| 500/500 [01:25<00:00,  5.88it/s]
#  39%|███▉      | 196/500 [00:33<00:44,  6.83it/s]
# 3303164_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  61%|██████    | 304/500 [00:54<00:46,  4.26it/s]
# 3305777_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:25<00:00,  5.86it/s]
#  33%|███▎      | 165/500 [00:27<00:38,  8.66it/s]
# 1854572_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:23<00:00,  6.02it/s]
#  27%|██▋       | 137/500 [00:25<00:53,  6.85it/s]
# 1421648_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  33%|███▎      | 164/500 [00:29<00:42,  7.94it/s]
# 1411309_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  79%|███████▉  | 395/500 [01:06<00:13,  8.03it/s]
# 1407524_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  81%|████████  | 406/500 [01:07<00:11,  7.95it/s]
# 1409345_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  91%|█████████ | 455/500 [01:15<00:06,  7.48it/s]
# 1429760_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:24<00:00,  5.91it/s]
#   4%|▍         | 20/500 [00:03<01:26,  5.57it/s]
# 1537650_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:22<00:00,  6.10it/s]
#  54%|█████▍    | 271/500 [00:41<00:36,  6.23it/s]
# 1373476_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  85%|████████▌ | 425/500 [01:06<00:08,  8.41it/s]
# 1396950_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.26it/s]
#   9%|▉         | 44/500 [00:06<00:51,  8.88it/s]
# 2269365_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:29<00:00,  5.61it/s]
#  43%|████▎     | 214/500 [00:40<00:35,  8.10it/s]
# 1945106_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:28<00:00,  5.64it/s]
#  37%|███▋      | 186/500 [00:32<00:39,  7.90it/s]
# 1676538_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  99%|█████████▊| 493/500 [01:25<00:00,  8.07it/s]
# 1657279_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:26<00:00,  5.78it/s]
#  20%|██        | 102/500 [00:16<01:07,  5.93it/s]
# 4207867_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:23<00:00,  5.97it/s]
#  52%|█████▏    | 262/500 [00:45<00:27,  8.50it/s]
# 3581983_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:25<00:00,  5.82it/s]
#  19%|█▊        | 93/500 [00:15<00:53,  7.65it/s]
# 5306225_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:23<00:00,  5.97it/s]
#  46%|████▌     | 231/500 [00:38<00:38,  6.97it/s]
# 4414672_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:26<00:00,  5.76it/s]
#  15%|█▍        | 74/500 [00:12<00:52,  8.05it/s]
# 4348831_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:20<00:00,  6.21it/s]
#  35%|███▌      | 176/500 [00:27<00:39,  8.20it/s]
# 1265561_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.31it/s]
# 100%|██████████| 500/500 [01:23<00:00,  5.96it/s]
# 100%|██████████| 500/500 [01:18<00:00,  6.36it/s]
#   8%|▊         | 42/500 [00:07<02:42,  2.82it/s]
# 2019084_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:22<00:00,  6.09it/s]
#   9%|▉         | 46/500 [00:06<00:58,  7.73it/s]
# 1060829_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  39%|███▉      | 194/500 [00:30<00:37,  8.24it/s]
# 1062349_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:18<00:00,  6.37it/s]
#  26%|██▌       | 130/500 [00:19<00:45,  8.12it/s]
# 1156286_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  72%|███████▏  | 360/500 [00:54<00:17,  7.80it/s]
# 1165903_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:17<00:00,  6.42it/s]
#  25%|██▌       | 127/500 [00:18<00:45,  8.18it/s]
# 5102826_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  84%|████████▍ | 419/500 [01:04<00:08,  9.10it/s]
# 5083936_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  94%|█████████▍| 471/500 [01:12<00:04,  6.62it/s]
# 5095869_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:16<00:00,  6.53it/s]
#  59%|█████▊    | 293/500 [00:46<00:31,  6.67it/s]
# 2605756_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:20<00:00,  6.22it/s]
#  38%|███▊      | 191/500 [00:30<00:42,  7.27it/s]
# 1765074_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:21<00:00,  6.17it/s]
#  98%|█████████▊| 492/500 [01:18<00:03,  2.28it/s]
# 4679412_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.27it/s]
#  23%|██▎       | 116/500 [00:18<00:45,  8.40it/s]
# 1046549_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  92%|█████████▏| 461/500 [01:14<00:05,  7.44it/s]
# 1050853_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:22<00:00,  6.07it/s]
#  35%|███▍      | 174/500 [00:27<00:38,  8.52it/s]
# 5957553_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  75%|███████▌  | 377/500 [01:01<00:16,  7.43it/s]
# 5930526_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:21<00:00,  6.14it/s]
#   2%|▏         | 12/500 [00:02<02:00,  4.06it/s]
# 4576121_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:20<00:00,  6.20it/s]
#   5%|▌         | 26/500 [00:04<01:03,  7.41it/s]
# 3538675_21015_1_0.png
# At most 8-bit PNG images are supported currently.
#  70%|███████   | 352/500 [00:55<00:17,  8.41it/s]
# 3533250_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:18<00:00,  6.40it/s]
# 100%|██████████| 500/500 [01:22<00:00,  6.05it/s]
#  52%|█████▏    | 261/500 [00:44<01:12,  3.29it/s]
# 3263329_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:31<00:00,  5.44it/s]
#  35%|███▌      | 176/500 [00:26<00:38,  8.43it/s]
# 5992058_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:16<00:00,  6.54it/s]
#  39%|███▉      | 196/500 [00:29<00:36,  8.27it/s]
# 2053296_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:18<00:00,  6.41it/s]
#  24%|██▍       | 119/500 [00:16<00:51,  7.44it/s]
# 5766407_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:20<00:00,  6.22it/s]
#  10%|█         | 52/500 [00:07<00:50,  8.94it/s]
# 2375244_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:18<00:00,  6.38it/s]
#  25%|██▌       | 126/500 [00:21<00:43,  8.58it/s]
# 5359879_21015_1_0.png
# At most 8-bit PNG images are supported currently.
# 100%|██████████| 500/500 [01:19<00:00,  6.29it/s]
# 100%|██████████| 500/500 [01:20<00:00,  6.21it/s]
# 100%|██████████| 500/500 [01:21<00:00,  6.16it/s]
#  66%|██████▌   | 328/500 [00:51<00:24,  7.00it/s]
# 4937462_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:18<00:00,  6.33it/s]
#  15%|█▌        | 76/500 [00:17<00:50,  8.44it/s]
# 3899155_21015_0_0.png
# min(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
# 100%|██████████| 500/500 [01:25<00:00,  5.84it/s]
# 100%|██████████| 500/500 [01:16<00:00,  6.54it/s]
